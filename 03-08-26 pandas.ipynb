# %%
#pip install pandas

# %%
import pandas as pd

# %%
a=[10,20,30,40]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
a=[2.5,4.5,3.5]
pd.Series(a)
# Out:
# 0    2.5
# 1    4.5
# 2    3.5
# dtype: float64

# %%
c=["python","java","dsa"]
pd.Series(c)
# Out:
# 0    python
# 1      java
# 2       dsa
# dtype: str

# %%
e=[True,False]
pd.Series(a)
# Out:
# 0    2.5
# 1    4.5
# 2    3.5
# dtype: float64

# %%
f=[5+3j,8+7j]
pd.Series(f)
# Out:
# 0    5.0+3.0j
# 1    8.0+7.0j
# dtype: complex128

# %%
d={"names":["pooja","priya","preethi"],"marks":[60,70,80]}
pd.DataFrame(d)
# Out:
#      names  marks
# 0    pooja     60
# 1    priya     70
# 2  preethi     80

# %%
d={"names":["pooja","priya","preethi"],"marks":[60,70,80]}
pd.DataFrame(d)
# Out:
#      names  marks
# 0    pooja     60
# 1    priya     70
# 2  preethi     80

# %%
data=pd.read_csv("student.csv")
data
# Out:
#     NAME         ID'S  AGE  GENDER DEPARATEMENT
# 0  Shiva  32350684956   21    male          cse
# 1   Rani  32350684978   20  female          ece
# 2    sai  32350684942   21    male          eee
# 3   roja   3250684942   21  female          cse

# %%
data.colums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data.colums
#
# File ~\Downloads\july31\chaithu\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
data.shape
# Out:
# (4, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of     NAME         ID'S  AGE  GENDER DEPARATEMENT
# 0  Shiva  32350684956   21    male          cse
# 1   Rani  32350684978   20  female          ece
# 2    sai  32350684942   21    male          eee
# 3   roja   3250684942   21  female          cse>

# %%
data1=pd.read_csv("ecommerce.csv")
data1
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 1        10002   1/2/2022         1435         Clothing  South         7
# 2        10003   1/3/2022         1860           Beauty   East         3
# 3        10004   1/4/2022         1270      Electronics   West         5
# 4        10005   1/5/2022         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996   9/5/2035         1289         Clothing   West         2
# 4996     14997   9/6/2035         1294           Beauty  North         3
# 4997     14998   9/7/2035         1450           Beauty   West         3
# 4998     14999   9/8/2035         1903      Electronics  South         4
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
data1.colum
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data1.colum
#
# File ~\Downloads\july31\chaithu\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colum'

# %%
data1.shape
# Out:
# (5000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of     NAME         ID'S  AGE  GENDER DEPARATEMENT
# 0  Shiva  32350684956   21    male          cse
# 1   Rani  32350684978   20  female          ece
# 2    sai  32350684942   21    male          eee
# 3   roja   3250684942   21  female          cse>
