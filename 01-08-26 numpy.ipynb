# %%
#pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
a=np.array(60)
print(a)
print(a.ndim)
print(type(a))
# Out:
# 60
# 0
# <class 'numpy.ndarray'>

# %%
a=np.array([20,30,50])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [20 30 50]
# 1
# <class 'numpy.ndarray'>

# %%
a=np.array([[20,30,50],[60,70,80]])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [[20 30 50]
#  [60 70 80]]
# 2
# <class 'numpy.ndarray'>

# %%
a=np.array([[[20,30,50],[60,70,80]],
           [[100,120,150],[200,250,300]]])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [[[ 20  30  50]
#   [ 60  70  80]]
#
#  [[100 120 150]
#   [200 250 300]]]
# 3
# <class 'numpy.ndarray'>

# %%
a=[1,2,3,4]
b=[5,6,7,8,]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
print(a+b)
# Out:
# [ 6  8 10 12]

# %%
c=np.sum(a)
print(c)
# Out:
# 10

# %%
d=np.sum(b)
print(d)
# Out:
# 26

# %%
e=np.mean(a)
print(e)
# Out:
# 2.5

# %%
f=np.mean(b)
print(f)
# Out:
# 6.5

# %%
x=np.array([1,2,3,"chaithu",8+9j,True,False])
print(x)
print(type(x))
# Out:
# ['1' '2' '3' 'chaithu' '(8+9j)' 'True' 'False']
# <class 'numpy.ndarray'>
